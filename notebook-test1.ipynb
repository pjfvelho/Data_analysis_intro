# %% [markdown]
# Pandas Test1

# %%
import pandas as pd
import numpy as np

# %% [raw]
# Series

# %%
mydata = ['Boat','Car','Bike','Truck']

myseries1 = pd.Series(mydata)

# %%
print(myseries1)

# %%
mydata = [1, 55, 99, 43]

myseries2 = pd.Series(mydata)

# %%
print(myseries2)

# %% [markdown]
# ## Data Frame

# %%
mydfdata = [('Boat', 1), ('Car', 55), ('Bike', 99), ('Truck', 43)]

mydf = pd.DataFrame(mydfdata)

# %%
mydf

# %%
mydf = pd.DataFrame(mydfdata, columns=['Thing', 'count'])

mydf

# %%
mydf['count']

# %%
type(mydf['Thing'])

# %%
print(mydfdata)

# %%
mydf.dtypes

# %% [markdown]
# ## Reading in data

# %%
df = pd.read_csv('../input/mr-beast-youtube-video-statistics/MrBeast_youtube_stats.csv')

# %%
#inspect the data

# %%
#Head / Tail
df.head()

# %%
df.tail()

# %%
df.tail()

# %%
df.dtypes

# %%
df.describe()

# %% [markdown]
# # Colums & Rows

# %%
df['viewCount']

# %%
df

# %%
df.loc[4]

# %% [markdown]
# #sunbsetting data

# %% [markdown]
# # Subsetting data

# %%
df

# %%
df = df[['title','description', 'publishTime','viewCount']]

# %%
df.head()

# %%
df.shape

# %%
#susetting rows

df['viewCount'] > 1000_000

# %%
df_subset2=df.query('viewCount>1000000')

# %%
df

# %%
df=df.loc[~df['viewCount'].isna()]

# %% [markdown]
# # Casting dtypes

# %%
df.dtypes

# %%
df['viewCount'].astype('int')

# %%
df['viewCount']= df['viewCount'].astype('int')
